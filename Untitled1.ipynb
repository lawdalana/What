# %%
x = {'key':555,'test':"hello"}
# del x['key']
print(x)
# Out:
# {'test': 'hello', 'key': 555}

# %%
# coding: utf-8

# In[1]:

import tweepy
from tweepy import OAuthHandler
import codecs
import time
from datetime import date, datetime
import json

# In[2]:

consumer_key = 'jmCRzWWRZjuhNo5Q2gHUXpOGd'
consumer_secret = '1wxvlRAjjRcP9TIuE2wnI7LlJ32pkxEc21wMkghMULNLCtKUyD'
access_token = '794344198312849408-vknnh03URiVLo4ijoNGYxYN7ZAmjYxB'
access_secret = 'PxWES0uBWpw7EcEv7IhG18kWn9yB8Kqsmwn6GbfwMRhrH'


# In[3]:
class StdOutListener(tweepy.StreamListener):

    def on_data(self, data):
        decoded = json.loads(data)
        del decoded['in_reply_to_status_id']
        del decoded['in_reply_to_status_id_str']
        del decoded['filter_level']
        del decoded['truncated']
        del decoded['lang']
        del decoded['in_reply_to_screen_name']
        del decoded['in_reply_to_user_id']
        del decoded['favorited']
        del decoded['possibly_sensitive']
        del decoded['geo']
        del decoded['source']
        del decoded['place']
        del decoded['in_reply_to_user_id_str']
        del decoded['id_str']
        del decoded['contributors']
        del decoded['expanded_url']
        del decoded['indices']
        del decoded['entities']['urls']
        del decoded['user']['profile_background_tile']
        del decoded['user']['profile_link_color']
        del decoded['user']['url']
        del decoded['user']['default_profile_image']
        del decoded['user']['protected']
        del decoded['user']['geo_enabled']
        del decoded['user']['notifications']
        del decoded['user']['utc_offset']
        del decoded['user']['profile_background_image_url']
        del decoded['user']['profile_background_color']
        del decoded['user']['time_zone']
        del decoded['user']['description']
        del decoded['user']['profile_sidebar_fill_color']
        del decoded['user']['follow_request_sent']
        del decoded['user']['is_translator']
        del decoded['user']['favourites_count']
        del decoded['user']['profile_image_url']
        del decoded['user']['profile_use_background_image']
        del decoded['user']['profile_text_color']
        del decoded['user']['profile_background_image_url_https']
        del decoded['user']['listed_count']
        del decoded['user']['verified']
        del decoded['user']['id_str']
        del decoded['user']['profile_image_url_https']
        del decoded['user']['contributors_enabled']
        del decoded['user']['profile_sidebar_border_color']
        del decoded['user']['default_profile']
        x = datetime.strptime(decoded['user']['created_at'],'%a %b %d %H:%M:%S %z %Y')
        if not decoded['retweeted']:
            print("user_id:"+ str(decoded['user']['id'])+","+
                  "user_name:"+ str(decoded['user']['name'])+","+
                  "user_screen_name:"+ str(decoded['user']['screen_name'])+","+
                  "user_friend_count:"+ str(decoded['user']['friends_count'])+","+
                  "user_follower_count:"+ str(decoded['user']['followers_count'])+","+
                  "user_status_count:"+ str(decoded['user']['statuses_count'])+","+
                  "user_location:"+ str(decoded['user']['location'])+","+
                  "user_created_at:"+ str()+","+
                  "post_id:"+ str(decoded['id'])+","+
                  "post_create_at:"+ str(decoded['timestamp_ms'])+","+
                  "post_favorite_count:"+ str(decoded['favorite_count'])+","+
                  "post_text:"+str(decoded['text'])+"\n")
            return True

    def on_error(self, status):
        print(status)

if __name__ == '__main__':

    #This handles Twitter authetification and the connection to Twitter Streaming API
    l = StdOutListener()
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_secret)
    stream = tweepy.Stream(auth, l)
    # dic = list()
    # with open("dict_twitter","r+",encoding="utf8") as test:



    #This line filter Twitter Streams to capture data by the keywords: 'python', 'javascript', 'ruby'
    # stream.filter(track=dic, async=True)
    stream.filter(track=['555'])
# Out:
# <class 'dict'>
# 2013-09-13 11:29:34+00:00
# user_id:1860323408,user_name:🍑💘,user_screen_name:20xxjae__,user_friend_count:2295,user_follower_count:434,user_status_count:13367,user_location:4ห้องหัวใจของนายอิมแจบอม,user_created_at:,post_id:874943288238784516,post_create_at:1497437710233,post_favorite_count:0,post_text:RT @runchanut: แจกกก🎉1บั้มเลือกได้ เนื่องจาก ครบรอบ4ปี แค่*รี+ฟอล* ไม่ฟอล=ตัดสิทธิ์!! ประกาศวันไหนบอกอีกที เม้นจะดีมาก555 ครั้งนี้…
#
# <class 'dict'>
# 2010-12-30 04:00:26+00:00
# user_id:232050039,user_name:ⓑⓔⓢⓣ✩,user_screen_name:_besttbest,user_friend_count:1072,user_follower_count:608,user_status_count:127023,user_location:None,user_created_at:,post_id:874943290021302272,post_create_at:1497437710658,post_favorite_count:0,post_text:RT @fhay_cotton_h: 🙆🏻ใส่ระหว่างไดร์ หรือหลังจากไดร์เสร็จ ครึ่งปั๊มพอ เฉพาะปลาย ผมนุ่มลื่นอย่างกับหมักผมมา555 หอมด้วย!…
#
# <class 'dict'>
# 2015-05-19 05:23:11+00:00
# user_id:3220016516,user_name:ウイ_FaTBeaR 🐻,user_screen_name:JutsuRyu,user_friend_count:70,user_follower_count:26,user_status_count:8136,user_location:กรุงเทพมหานคร, ประเทศไทย,user_created_at:,post_id:874943290864320512,post_create_at:1497437710859,post_favorite_count:0,post_text:@jahhsiri เอาที่มึงพร้อมค่อยเล่า555
#
# <class 'dict'>
# 2017-06-07 12:44:57+00:00
# user_id:872434199982071810,user_name:1억만들기▶486hp.com◀,user_screen_name:zwjcpmlqbimfx,user_friend_count:0,user_follower_count:0,user_status_count:23,user_location:None,user_created_at:,post_id:874943290222575616,post_create_at:1497437710706,post_favorite_count:0,post_text:소셜그래프게임,#소셜그래프게임
# 그래프게임,#그래프게임
# 그래프게임주소♥https://t.co/K6xUNY1R8l♥가입코드:555
# 쉽게돈벌기,※만원으로 백만원 만들기※ https://t.co/RNxUzRJNjj
#
# <class 'dict'>
# 2013-02-21 10:41:58+00:00
# user_id:1203994357,user_name:Newtyounext,user_screen_name:MTandBB937,user_friend_count:88,user_follower_count:56,user_status_count:25852,user_location:Thailand,user_created_at:,post_id:874943293599105024,post_create_at:1497437711511,post_favorite_count:0,post_text:RT @bbeammatk: นี่คือเอกโย่ของคนชิคคนะค่ะ!!555 #วิถีคนชิค #JB #เจบี #แจบอม #GOT7  #Got7Thailandtour2017 #Got7thailandtour…
#
# <class 'dict'>
# 2016-01-13 11:20:30+00:00
# user_id:4752767070,user_name:พ่อจ๋าหนูแซะตามแม่🙏,user_screen_name:Min_Trar,user_friend_count:71,user_follower_count:5,user_status_count:3750,user_location:ประเทศไทย,user_created_at:,post_id:874943297508134913,post_create_at:1497437712443,post_favorite_count:0,post_text:RT @16_Mayyz: ไม่ต้องประกาศว่าคบกันนะลูกหมีก็ถือเคล็ดแต่พวกเรารู้ พวกเราสัมผัสได้ เดี๋ยวๆเขายังไม่ได้คบกันแมะ 555 #เต้ยเชียร์ https://t.co/…
#
# <class 'dict'>
# 2015-03-15 15:05:35+00:00
# user_id:3085685840,user_name::฿,user_screen_name:pumpkinnyy,user_friend_count:326,user_follower_count:61,user_status_count:35563,user_location:None,user_created_at:,post_id:874943298665816064,post_create_at:1497437712719,post_favorite_count:0,post_text:RT @shsseoxx: คนที่ชอบอ่านหนังสือ จะเข้าใจโมเม้นต์เวลาที่ได้อ่านหนังสือที่ชอบมากๆซักเล่ม แบบอยากจะอ่านมันให้ถึงตอนจบ แต่ก็ไม่อยากให้จบ มีใค…
#
# <class 'dict'>
# 2017-03-29 01:35:19+00:00
# user_id:846898531923214341,user_name:ขนุนหนัง®🔯,user_screen_name:khnunn_kd,user_friend_count:285,user_follower_count:19,user_status_count:923,user_location:Black hole ❗,user_created_at:,post_id:874943300364455937,post_create_at:1497437713124,post_favorite_count:0,post_text:@ironkong ผวนเลย 555
#
# <class 'dict'>
# 2015-12-24 09:27:09+00:00
# user_id:4642426166,user_name:TENPONY🌟텐텐,user_screen_name:Eveeveapy,user_friend_count:376,user_follower_count:997,user_status_count:92322,user_location:โพนี่แลนด์แดนพารากอน,user_created_at:,post_id:874943301924790272,post_create_at:1497437713496,post_favorite_count:0,post_text:RT @Spraewchana: ทุกครั้งจะกดสคริปโฆษณา แต่อันนี้กดไม่ลง 555 #CherryBomb https://t.co/9eFtENnwjl
#
# <class 'dict'>
# 2011-05-24 12:39:01+00:00
# user_id:304388458,user_name:สมศรี มีดีที่ไห,user_screen_name:realsomzee,user_friend_count:52,user_follower_count:80,user_status_count:26265,user_location:Chiang rai,Thailand,user_created_at:,post_id:874943306253312001,post_create_at:1497437714528,post_favorite_count:0,post_text:RT @hiyuura: ผช.คนนี้โดนเพื่อนยุให้ถ่ายรูปกับหมาของบอสเลียนแบบไททานิค ไปๆมาไ ฮีเลยถ่ายเลียนแบบเรื่องอื่นด้วยซะเลย โอ๊ยย ฮาา 555…
#
# <class 'dict'>
# 2016-06-02 08:16:48+00:00
# user_id:738283209725612032,user_name:ตะมุตะมิแตแต❣️,user_screen_name:Faipimm,user_friend_count:64,user_follower_count:41,user_status_count:24615,user_location:Thailand,user_created_at:,post_id:874943308295950337,post_create_at:1497437715015,post_favorite_count:0,post_text:RT @Myojojung: มีความงอแง เอาแต่ใจเบาๆ แล้วดูเมมเบอร์แต่ละคน เอ็นดูยัยหนูหนักมาก ทำตัวเหมือนเป็นมักเน่ แต่คือแก่อันดับ4ของวง 555+…
#
# <class 'dict'>
# 2014-03-25 16:33:44+00:00
# user_id:2411270335,user_name:เตนล์เป็นก้อนๆ,user_screen_name:KTaooo,user_friend_count:728,user_follower_count:139,user_status_count:78331,user_location:กาแล็กซี่กับหมีแพนด้า,user_created_at:,post_id:874943308694298625,post_create_at:1497437715110,post_favorite_count:0,post_text:RT @Spraewchana: ทุกครั้งจะกดสคริปโฆษณา แต่อันนี้กดไม่ลง 555 #CherryBomb https://t.co/9eFtENnwjl
#
# <class 'dict'>
# 2017-03-18 03:44:08+00:00
# user_id:842944684410392576,user_name:Jutakan lee,user_screen_name:LeeJutakan,user_friend_count:69,user_follower_count:3,user_status_count:2566,user_location:None,user_created_at:,post_id:874943309445185536,post_create_at:1497437715289,post_favorite_count:0,post_text:RT @poisypat: หัวใจยังหม่นหมองอยู่ ทำขนมไปมโนไป 555 #มโนรีพอร์ตรายงาน #BoomKrittapak #peakpeemapol @BoomKrittapak @peakpeemapol https://t.c…
#
# <class 'dict'>
# 2017-04-26 20:47:22+00:00
# user_id:857335315702267904,user_name:เราไงลูกชิ้นปลาเส้น,user_screen_name:PAmbully1,user_friend_count:28,user_follower_count:2,user_status_count:1864,user_location:None,user_created_at:,post_id:874943309780721664,post_create_at:1497437715369,post_favorite_count:0,post_text:RT @nokweed_love: @MyYixingniii กระโดดกอดแรงๆ 555 เราโหวตจนมือจะหงิกแถบแทบจะไม่ขยับ เราต้องสู้ไปด้วยกันนะคะ 😱😭
#
# <class 'dict'>
# 2015-10-17 16:31:34+00:00
# user_id:3926649614,user_name:แก้มของแบมแบม,user_screen_name:Real_PcpB,user_friend_count:388,user_follower_count:80,user_status_count:7509,user_location:MarkBam Shipper,user_created_at:,post_id:874943309700935680,post_create_at:1497437715350,post_favorite_count:0,post_text:@MB_destiny9397 วาร์ปไปกินได้มั้ยล่า555
#
# <class 'dict'>
# 2017-05-30 07:23:45+00:00
# user_id:869454266208878592,user_name:รักเชียร์  💙 เต้ย,user_screen_name:suratchunya,user_friend_count:80,user_follower_count:145,user_status_count:1070,user_location:None,user_created_at:,post_id:874943310837596160,post_create_at:1497437715621,post_favorite_count:0,post_text:เมื่อไหร่จะได้ #กองพันรักพิเศษที่หนึ่ง เนี่ยยย  #เต้ยเชียร์ ได้ข่าวเพิ่งจองเมื่อวาน 555
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-5869085c0082> in <module>()
#      59     #This line filter Twitter Streams to capture data by the keywords: 'python', 'javascript', 'ruby'
#      60     # stream.filter(track=dic, async=True)
# ---> 61     stream.filter(track=['555'])
#
# c:\program files\python35\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# c:\program files\python35\lib\site-packages\tweepy\streaming.py in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# c:\program files\python35\lib\site-packages\tweepy\streaming.py in _run(self)
#     261                     self.snooze_time = self.snooze_time_step
#     262                     self.listener.on_connect()
# --> 263                     self._read_loop(resp)
#     264             except (Timeout, ssl.SSLError) as exc:
#     265                 # This is still necessary, as a SSLError can actually be
#
# c:\program files\python35\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     311             length = 0
#     312             while not resp.raw.closed:
# --> 313                 line = buf.read_line().strip()
#     314                 if not line:
#     315                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# c:\program files\python35\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     177             else:
#     178                 start = len(self._buffer)
# --> 179             self._buffer += self._stream.read(self._chunk_size)
#     180
#     181     def _pop(self, length):
#
# c:\program files\python35\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# c:\program files\python35\lib\http\client.py in read(self, amt)
#     446             # Amount is given, implement using readinto
#     447             b = bytearray(amt)
# --> 448             n = self.readinto(b)
#     449             return memoryview(b)[:n].tobytes()
#     450         else:
#
# c:\program files\python35\lib\http\client.py in readinto(self, b)
#     476
#     477         if self.chunked:
# --> 478             return self._readinto_chunked(b)
#     479
#     480         if self.length is not None:
#
# c:\program files\python35\lib\http\client.py in _readinto_chunked(self, b)
#     571         try:
#     572             while True:
# --> 573                 chunk_left = self._get_chunk_left()
#     574                 if chunk_left is None:
#     575                     return total_bytes
#
# c:\program files\python35\lib\http\client.py in _get_chunk_left(self)
#     539                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     540             try:
# --> 541                 chunk_left = self._read_next_chunk_size()
#     542             except ValueError:
#     543                 raise IncompleteRead(b'')
#
# c:\program files\python35\lib\http\client.py in _read_next_chunk_size(self)
#     499     def _read_next_chunk_size(self):
#     500         # Read the next chunk size from the file
# --> 501         line = self.fp.readline(_MAXLINE + 1)
#     502         if len(line) > _MAXLINE:
#     503             raise LineTooLong("chunk size")
#
# c:\program files\python35\lib\socket.py in readinto(self, b)
#     574         while True:
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#     578                 self._timeout_occurred = True
#
# c:\program files\python35\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#     935                   "non-zero flags not allowed in calls to recv_into() on %s" %
#     936                   self.__class__)
# --> 937             return self.read(nbytes, buffer)
#     938         else:
#     939             return socket.recv_into(self, buffer, nbytes, flags)
#
# c:\program files\python35\lib\ssl.py in read(self, len, buffer)
#     797             raise ValueError("Read on closed or unwrapped SSL socket.")
#     798         try:
# --> 799             return self._sslobj.read(len, buffer)
#     800         except SSLError as x:
#     801             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# c:\program files\python35\lib\ssl.py in read(self, len, buffer)
#     581         """
#     582         if buffer is not None:
# --> 583             v = self._sslobj.read(len, buffer)
#     584         else:
#     585             v = self._sslobj.read(len)
#
# KeyboardInterrupt:
